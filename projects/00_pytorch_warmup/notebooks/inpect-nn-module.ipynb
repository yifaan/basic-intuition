# %%
import torch.nn as nn

class Bad(nn.Module):
    def __init__(self):
        self.w = nn.Parameter(nn.init.normal_(torch.empty(1, 1)))
1
class Good(nn.Module):
    def __init__(self):
        super().__init__()
        self.w = nn.Parameter(nn.init.normal_(torch.empty(1, 1)))

print("bad parameters:", list(Bad().parameters()))
print("good parameters:", list(Good().parameters()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 12
#       9         super().__init__()
#      10         self.w = nn.Parameter(nn.init.normal_(torch.empty(1, 1)))
# ---> 12 print("bad parameters:", list(Bad().parameters()))
#      13 print("good parameters:", list(Good().parameters()))
#
# Cell In[1], line 5, in Bad.__init__(self)
#       4 def __init__(self):
# ----> 5     self.w = nn.Parameter(nn.init.normal_(torch.empty(1, 1)))
#
# NameError: name 'torch' is not defined
